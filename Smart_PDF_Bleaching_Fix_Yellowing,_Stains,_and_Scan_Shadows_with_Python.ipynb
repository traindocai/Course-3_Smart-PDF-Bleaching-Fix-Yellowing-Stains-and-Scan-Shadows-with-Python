# %% [markdown]
# <a href="https://colab.research.google.com/github/traindocai/Course-3_Smart-PDF-Bleaching-Fix-Yellowing-Stains-and-Scan-Shadows-with-Python/blob/main/Smart_PDF_Bleaching_Fix_Yellowing%2C_Stains%2C_and_Scan_Shadows_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Course 3: Converting your PDFs to Grayscale**
#
# IMPORTANT: Once the notebook opens, go to File > Save a copy in Drive. If you do not save a copy, your progress and changes will not be saved to your Google Drive.
#
# Next, download the PDF file from the lecture to your computer, name it 'my_file', and then upload it to your Google Drive.

# %% [markdown]
# 🌉 **Step 1: Mounting your PDF in Google Drive**
#
# Before we can use Python to view a PDF document, we have to build a bridge between our notebook and our Google Drive storage.
#
# **Instructions:**
#
# *   Click into the first empty cell below.
# *   Type the following:
#
# `from google.colab import drive`
#
# `drive.mount('/content/drive')`
# *   Press the Play button (the circle with a triangle).
#
# ⚠️ When you run the code, a window will pop up asking you to **"Connect to Google Drive"**. Click that button, and then select **"Continue"** to grant access. Sometimes, depending on the browser or account settings, the pop-up might ask you to **select your Google Account** before you see the "Continue" button.
#
# ---
#
#
#
# 💡 Key Concepts:
#
# `from google.colab import drive`
#
# *   We import the `drive` module from the `google.colab` library by using the keywords `from` and `import`.
# *   A **library** is a collection of modules that lets you perform complex tasks without writing code from scratch.
# *   A **module** is a specific file inside a library that contains the actual code "instructions."
# *   A Keyword is a "Reserved Word" that Python already knows by heart. Because these words have a special job to do, you cannot use them for your own names (like naming a variable).
#
#
# ---
# `drive.mount('/content/drive')`
#
# *   When we call the `.mount()`function from the `drive` module, we are giving the Python script permission to "log in" to your storage.
# *   By telling the computer to mount at `/content/drive`, we are creating a virtual folder where all your personal Google Drive files will suddenly appear.
#
#
# 🔄 Troubleshooting: If the notebook stops responding, simply go to the top menu bar and follow this path: Runtime > Restart session. After you restart the session, you will need to re-run your code cells (starting from the top).

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 1</b></summary>
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# **⚙️ Step 2: Installing the Engine**
#
# **Instructions:**
#
#
# *   In the next cell, type the following:`!pip install pymupdf`
# *   Press the Play button.
#
#
#
# ---
#
# 💡 Key Concepts:
#
#
# *   PyMuPDF is the specialized library we use for opening and manipulating PDFs. To get it into our environment, we use PIP.
# *   PIP (Package Installer for Python) is used to install and manage libraries that do not come built-in with Python.
# *   The Exclamation Point (!): This is a "shell escape." It tells Google Colab: "*Don't treat this as Python code; talk directly to the Operating System to run a command.*"

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 2</b></summary>
#
# ```python
# !pip install pymupdf
#
#
# Expected Output:
# Collecting pymupdf
#   Downloading pymupdf-1.27.1-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.27.1-cp310-abi3-manylinux_2_28_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 64.5 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.27.1

# %% [markdown]
# **📦 Step 3: Importing the fitz module**
#
# **Instructions:**
#
#
# *   In the next cell, type the following: `import fitz`
# *   Press the Play button.
#
#
#
# ---
#
# 💡 Key Concepts:
#
# The fitz module "reads" the complex structure of a PDF file (which is usually just a set of mathematical instructions that define the shapes, lines, and curves on a page) and converts those mathematical instructions into a Pixmap—a grid of coloured dots (pixels).

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 3</b></summary>
#
# ```python
# import fitz

# %% [markdown]
# 📗 **Step 4: Locating the PDF document**
#
# Now that the "bridge" is built and the engine is installed, we need to tell Python exactly which file to pick up.
#
# **4.1 Instructions:**
#
#
#
# *   In the next cell, type the following: `file_path = '/content/drive/MyDrive/my_file.pdf'`
#
# *   Press the Play button.
#
#
#
# ⚠️ Computers need a specific address. `/content/drive/MyDrive/` is the standard address for your main Google Drive folder. We add the name of our PDF—including the .pdf extension (`my_file.pdf`)—to the end of that address. Finally, we store this entire "address" in a variable called `file_path`.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 4.1</b></summary>
#
# ```python
# file_path = '/content/drive/MyDrive/my_file.pdf'

# %% [markdown]
# **4.2 Instructions:**
#
# *   In the next cell, type the following: `doc = fitz.open(file_path)`
# *   Press the Play button.
#
#
#
# ⚠️ We call the `.open()` function from the `fitz` module and pass the `file_path` variable to the function to create a `doc` object—a container holding your PDF data.
#
# 💡 `file_path` is the argument you are passing to that function. An argument is the specific value you plug into a function to tell it exactly what data to work with.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 4.2</b></summary>
#
# ```python
# doc = fitz.open(file_path)

# %% [markdown]
# **4.3 Instructions:**
#
#
#
# *   In the next cell, type the following: `page = doc[0]`
# *   Press the Play button.
#
#
# ⚠️ Zero-indexing: Python starts counting at 0. Therefore, `doc[0]` targets the very first page of your PDF file. This stores the first page in the `page` object so we can work with it.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 4.3</b></summary>
#
# ```python
# page = doc[0]

# %% [markdown]
# 🧰 **Step 5: The Tools (Libraries)**
#
# Converting a PDF to grayscale is a fundamental data transformation. In computer vision, an image is processed as a multi-dimensional array—essentially a massive grid of numerical values representing pixel intensity.
#
# To manipulate this data efficiently, we use two tools:
#
# 1. **NumPy: The Mathematical Engine**
#
# 2. **OpenCV: The Computer Vision Specialist**
#
#
# ---
#
#
#
# **Instructions:**
#
# *   In the next cell, type the following:
#
# `import numpy as np`
#
# `import cv2`
#
#
#
#
# *   Press the Play button.
#
# ---
#
# 💡 Key Concepts:
#
# *   The Math Expert: We import the `numpy` (NumPy) library which processes millions of pixels all at once using high-speed math.
# *   The Alias (`as np`): This is a nickname so we do not have to type the full name every time we call a function from the NumPy library.
# *   OpenCV recalculates the image. It deletes the colour data and leaves only the brightness, giving you a sharp, distraction-free scan.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 5</b></summary>
#
# ```python
# import numpy as np
# import cv2

# %% [markdown]
# 📏 **Step 6: The Measuring Tape (Dimensions)**
#
# Before we process an image, we need to know its size.
#
# **Instructions:**
#
#
# *   In the next cell, type the following:
#
# `page_rect = page.rect`
#
# `page_rect`
#
# *   Press the Play button.
#
#
#
# ---
# 💡 Key Concepts:
#
# We call the `.rect` property on the `page` object to create the `page_rect` object, which captures the boundaries of our PDF page rectangle.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 6</b></summary>
#
# ```python
# Rect(0.0, 0.0, 439.6000061035156, 763.7999877929688)

# %% [markdown]
# **📸 Step 7: Rendering the Snapshot**
#
# We will now perform Rendering, the act of taking a picture of the PDF page.
#
# **Instructions:**
# *   In the next cell, type the following:
#
# `pix = page.get_pixmap(dpi=300, colorspace=fitz.csGRAY)`
#
# `pix`
# *   Press the Play button.
#
#
#
#
# ---
# 💡 Key Concepts:
#
#
# *   We call the `.get_pixmap()` method on the `page` object. A PDF is not naturally an image; it is a list of mathematical instructions (like "draw a line here" or "put this letter there"). The `.get_pixmap()` method takes those instructions and converts them into a Pixmap—a rectangular grid (a matrix) of individual grayscale pixels. We store the Pixmap into the `pix `object.
# *   We set `dpi` (parameter) to `300` (argument). This is the professional standard for high-quality printing.
# *  We set the `colorspace` parameter to the `fitz.csGRAY` argument to force the output to be a single-channel grayscale image (black, white, and shades of gray).

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 7</b></summary>
#
# ```python
# Pixmap(DeviceGray, (0, 0, 1832, 3183), 0)

# %% [markdown]
# **🌑 Step 8: The Grayscale Transformation**
#
# Finally, we will perform Reshaping which is the process of taking a flat list of numbers (1D NumPy array) and folding it into a specific structure— a 2D grid of Rows (Height) and Columns (Width).
#
# **Instructions:**
# *   In the next cell, type the following:
#
# `gray = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.h, pix.w)`
#
# `gray`
#
# *   Press the Play button.
#
#
#
#
# ---
# 💡 Key Concepts:
#
#
# *   We call the`.frombuffer()` function from the NumPy library (`np`). This returns a 1D NumPy array object.
# *   `pix.samples`: This is the "raw ingredients" (the flat list of numbers) we are feeding into the function.
# *   We set the `dtype` parameter to Unsigned 8-bit Integer. "8-bit" means every number is a whole integer between 0 (Pure Black) and 255 (Pure White).
# *  We pass the two properties (`pix.h`, `pix.w`) to the `.reshape()` method as arguments to tell NumPy to organize the data into 3,183 rows and that each row must be exactly 1,832 pixels wide.
# *   We then call the `.reshape()` method on the NumPy array object to create the `gray` object which is a 2D grid of Rows and Columns.

# %% [markdown]
# <details>
# <summary><b>Click here to see the solution for Step 8</b></summary>
#
# ```python
# array([[170, 170, 170, ..., 182, 182, 182],
#        [170, 170, 170, ..., 182, 182, 182],
#        [170, 170, 170, ..., 182, 182, 182],
#        ...,
#        [167, 167, 169, ..., 196, 196, 196],
#        [167, 167, 169, ..., 196, 196, 196],
#        [167, 167, 169, ..., 196, 196, 196]], dtype=uint8)

# %% [markdown]
# 📺 **Step 9: Viewing the Gray PDF Page**
#
# **Instructions:**
# *   In the next cell, type the following:
#
# `cv2.imwrite('grayscale_output.png', gray)`
#
# *   Press the Play button.
#
#
# ---
# 💡 Key Concepts:
#
# *   We call the `.imwrite()` (Image Write) function from the `cv2` library. This function "exports" your data from Python's memory into a file you can actually open.
# *   It requires two arguments:
#     1. `'grayscale_output.png'`: The name you want to give the file. It must be in quotes because it is a string.
#     2. `gray`: The grayscale image object (the data) you just created.
#
#
#
# ---
#
# **How to find your file in Google Colab:**
# 1. Click the Folder icon (📁) on the left sidebar.
# 2. If you don't see your file yet, click the Refresh icon (the folder with a circular arrow) at the top of the file list.
# 3. **To Preview**: Double-click `grayscale_output.png` to see it inside Colab.
# 4. **To Download:** Hover over the file name, click the three dots (⋮), and select Download.
